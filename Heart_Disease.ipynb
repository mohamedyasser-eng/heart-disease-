# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

import os
print(os.listdir())

import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn import svm
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb
from keras.models import Sequential
from keras.layers import Dense
# Out:
# ['env', 'heart.csv', 'Heart_Disease.ipynb']
# WARNING:tensorflow:From c:\python\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
dataset = pd.read_csv("heart.csv")

# %%
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
dataset.shape
# Out:
# (1025, 14)

# %%
dataset.head(5)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
dataset.sample(5)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 682   59    1   0       164   176    1        0       90      0      1.0
# 663   58    0   0       100   248    0        0      122      0      1.0
# 897   52    1   1       134   201    0        1      158      0      0.8
# 433   37    1   2       130   250    0        1      187      0      3.5
# 314   40    1   3       140   199    0        1      178      1      1.4
#
#      slope  ca  thal  target
# 682      1   2     1       0
# 663      1   0     2       1
# 897      2   1     2       1
# 433      0   0     2       1
# 314      2   0     3       1

# %%
dataset.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# min       0.000000     0.000000    71.000000     0.000000     0.000000
# 25%       0.000000     0.000000   132.000000     0.000000     0.000000
# 50%       0.000000     1.000000   152.000000     0.000000     0.800000
# 75%       0.000000     1.000000   166.000000     1.000000     1.800000
# max       1.000000     2.000000   202.000000     1.000000     6.200000
#
#              slope           ca         thal       target
# count  1025.000000  1025.000000  1025.000000  1025.000000
# mean      1.385366     0.754146     2.323902     0.513171
# std       0.617755     1.030798     0.620660     0.500070
# min       0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     0.000000     2.000000     0.000000
# 50%       1.000000     0.000000     2.000000     1.000000
# 75%       2.000000     1.000000     3.000000     1.000000
# max       2.000000     4.000000     3.000000     1.000000

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %% [markdown]
# Let's understand our columns better:

# %%
info = ["age","1: male, 0: female","chest pain type, 1: typical angina, 2: atypical angina, 3: non-anginal pain, 4: asymptomatic","resting blood pressure"," serum cholestoral in mg/dl","fasting blood sugar > 120 mg/dl","resting electrocardiographic results (values 0,1,2)"," maximum heart rate achieved","exercise induced angina","oldpeak = ST depression induced by exercise relative to rest","the slope of the peak exercise ST segment","number of major vessels (0-3) colored by flourosopy","thal: 3 = normal; 6 = fixed defect; 7 = reversable defect"]



for i in range(len(info)):
    print(dataset.columns[i]+":\t\t\t"+info[i])
# Out:
# age:			age
# sex:			1: male, 0: female
# cp:			chest pain type, 1: typical angina, 2: atypical angina, 3: non-anginal pain, 4: asymptomatic
# trestbps:			resting blood pressure
# chol:			 serum cholestoral in mg/dl
# fbs:			fasting blood sugar > 120 mg/dl
# restecg:			resting electrocardiographic results (values 0,1,2)
# thalach:			 maximum heart rate achieved
# exang:			exercise induced angina
# oldpeak:			oldpeak = ST depression induced by exercise relative to rest
# slope:			the slope of the peak exercise ST segment
# ca:			number of major vessels (0-3) colored by flourosopy
# thal:			thal: 3 = normal; 6 = fixed defect; 7 = reversable defect

# %% [markdown]
# Analysing the 'target' variable

# %%
dataset["target"].describe()
# Out:
# count    1025.000000
# mean        0.513171
# std         0.500070
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: target, dtype: float64

# %%
dataset["target"].unique()
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
# Clearly, this is a classification problem, with the target variable having values '0' and '1'
#
# Checking correlation between columns

# %%
print(dataset.corr()["target"].abs().sort_values(ascending=False))
# Out:
# target      1.000000
# oldpeak     0.438441
# exang       0.438029
# cp          0.434854
# thalach     0.422895
# ca          0.382085
# slope       0.345512
# thal        0.337838
# sex         0.279501
# age         0.229324
# trestbps    0.138772
# restecg     0.134468
# chol        0.099966
# fbs         0.041164
# Name: target, dtype: float64

# %% [markdown]
# Exploratory Data Analysis (EDA)
#
# First, analysing the target variable:

# %%
y = dataset["target"]

sns.countplot(y)


target_temp = dataset.target.value_counts()

print(target_temp)
# Out:
# target
# 1    526
# 0    499
# Name: count, dtype: int64

# %%
print("Percentage of patience without heart problems: "+str(round(target_temp[0]*100/303,2)))
print("Percentage of patience with heart problems: "+str(round(target_temp[1]*100/303,2)))
# Out:
# Percentage of patience without heart problems: 164.69
# Percentage of patience with heart problems: 173.6

# %% [markdown]
# We'll analyse 'sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca' and 'thal' features
#
# Analysing the 'Sex' feature

# %%
dataset["sex"].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
sns.countplot(x="sex", hue="target", data=dataset)
plt.show()

# %% [markdown]
# Analysing the 'Chest Pain Type' feature

# %%
dataset["cp"].unique()
# Out:
# array([0, 1, 2, 3], dtype=int64)

# %%
sns.countplot(x="cp", hue="target", data=dataset)
plt.show()

# %% [markdown]
# Analysing the FBS feature

# %%
dataset["fbs"].describe()
# Out:
# count    1025.000000
# mean        0.149268
# std         0.356527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: fbs, dtype: float64

# %%
dataset["fbs"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
sns.countplot(x="fbs", hue="target", data=dataset)
plt.show()

# %% [markdown]
# Analysing the restecg feature

# %%
dataset["restecg"].unique()
# Out:
# array([1, 0, 2], dtype=int64)

# %%
sns.countplot(x="restecg", hue="target", data=dataset)
plt.show()

# %% [markdown]
# Analysing the 'exang' feature

# %%
dataset["exang"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
sns.countplot(x="exang", hue="target", data=dataset)
plt.show()

# %% [markdown]
# Analysing the Slope feature

# %%
dataset["slope"].unique()
# Out:
# array([2, 0, 1], dtype=int64)

# %%
sns.countplot(x="slope", hue="target", data=dataset)
plt.show()

# %% [markdown]
# Analysing the 'ca' feature

# %%
dataset["ca"].unique()
# Out:
# array([2, 0, 1, 3, 4], dtype=int64)

# %%
sns.countplot(x="ca", data=dataset)
plt.show()

# %% [markdown]
#  Analysing the 'thal' feature

# %%
dataset["thal"].unique()
# Out:
# array([3, 2, 1, 0], dtype=int64)

# %%
sns.countplot(x="thal", hue="target", data=dataset)
plt.show()

# %%
sns.distplot(dataset["thal"])
# Out:
# <Axes: xlabel='thal', ylabel='Density'>

# %% [markdown]
# IV. Train Test split

# %%
predictors = dataset.drop("target",axis=1)
target = dataset["target"]

X_train,X_test,Y_train,Y_test = train_test_split(predictors,target,test_size=0.20,random_state=0)

# %%
X_train.shape
# Out:
# (820, 13)

# %%
X_train.shape
# Out:
# (820, 13)

# %%
Y_train.shape
# Out:
# (820,)

# %%
Y_test.shape
# Out:
# (205,)

# %% [markdown]
# Logistic Regression

# %%
lr = LogisticRegression()

lr.fit(X_train,Y_train)

Y_pred_lr = lr.predict(X_test)

# %%
Y_pred_lr.shape
# Out:
# (205,)

# %%
score_lr = round(accuracy_score(Y_pred_lr,Y_test)*100,2)

print("The accuracy score achieved using Logistic Regression is: "+str(score_lr)+" %")
# Out:
# The accuracy score achieved using Logistic Regression is: 86.34 %

# %% [markdown]
# Naive Bayes

# %%
nb = GaussianNB()

nb.fit(X_train,Y_train)

Y_pred_nb = nb.predict(X_test)

# %%
Y_pred_nb.shape
# Out:
# (205,)

# %%
score_nb = round(accuracy_score(Y_pred_nb,Y_test)*100,2)

print("The accuracy score achieved using Naive Bayes is: "+str(score_nb)+" %")
# Out:
# The accuracy score achieved using Naive Bayes is: 85.37 %

# %% [markdown]
# SVM

# %%
sv = svm.SVC(kernel='linear')

sv.fit(X_train, Y_train)

Y_pred_svm = sv.predict(X_test)

# %%
Y_pred_svm.shape
# Out:
# (205,)

# %%
score_svm = round(accuracy_score(Y_pred_svm,Y_test)*100,2)

print("The accuracy score achieved using Linear SVM is: "+str(score_svm)+" %")
# Out:
# The accuracy score achieved using Linear SVM is: 83.9 %

# %% [markdown]
# K Nearest Neighbors

# %%
knn = KNeighborsClassifier(n_neighbors=7)
knn.fit(X_train,Y_train)
Y_pred_knn=knn.predict(X_test)

# %%
Y_pred_knn.shape
# Out:
# (205,)

# %%
score_knn = round(accuracy_score(Y_pred_knn,Y_test)*100,2)

print("The accuracy score achieved using KNN is: "+str(score_knn)+" %")
# Out:
# The accuracy score achieved using KNN is: 72.2 %

# %% [markdown]
# Decision Tree

# %%
max_accuracy = 0


for x in range(200):
    dt = DecisionTreeClassifier(random_state=x)
    dt.fit(X_train,Y_train)
    Y_pred_dt = dt.predict(X_test)
    current_accuracy = round(accuracy_score(Y_pred_dt,Y_test)*100,2)
    if(current_accuracy>max_accuracy):
        max_accuracy = current_accuracy
        best_x = x
        



dt = DecisionTreeClassifier(random_state=best_x)
dt.fit(X_train,Y_train)
Y_pred_dt = dt.predict(X_test)

# %%
print(Y_pred_dt.shape)
# Out:
# (205,)

# %%
score_dt = round(accuracy_score(Y_pred_dt,Y_test)*100,2)

print("The accuracy score achieved using Decision Tree is: "+str(score_dt)+" %")
# Out:
# The accuracy score achieved using Decision Tree is: 100.0 %

# %% [markdown]
# Random Forest

# %%
max_accuracy = 0


for x in range(2000):
    rf = RandomForestClassifier(random_state=x)
    rf.fit(X_train,Y_train)
    Y_pred_rf = rf.predict(X_test)
    current_accuracy = round(accuracy_score(Y_pred_rf,Y_test)*100,2)
    if(current_accuracy>max_accuracy):
        max_accuracy = current_accuracy
        best_x = x
        


rf = RandomForestClassifier(random_state=best_x)
rf.fit(X_train,Y_train)
Y_pred_rf = rf.predict(X_test)

# %%
Y_pred_rf.shape
# Out:
# (205,)

# %%
score_rf = round(accuracy_score(Y_pred_rf,Y_test)*100,2)

print("The accuracy score achieved using Decision Tree is: "+str(score_rf)+" %")
# Out:
# The accuracy score achieved using Decision Tree is: 100.0 %

# %% [markdown]
# XGBoost

# %%
xgb_model = xgb.XGBClassifier(objective="binary:logistic", random_state=42)
xgb_model.fit(X_train, Y_train)

Y_pred_xgb = xgb_model.predict(X_test)

# %%
Y_pred_xgb.shape
# Out:
# (205,)

# %%
score_xgb = round(accuracy_score(Y_pred_xgb,Y_test)*100,2)

print("The accuracy score achieved using XGBoost is: "+str(score_xgb)+" %")
# Out:
# The accuracy score achieved using XGBoost is: 100.0 %

# %% [markdown]
# Neural Network

# %%
model = Sequential()
model.add(Dense(11,activation='relu',input_dim=13))
model.add(Dense(1,activation='sigmoid'))

model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From c:\python\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\python\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.fit(X_train,Y_train,epochs=300)
# Out:
# Epoch 1/300
# WARNING:tensorflow:From c:\python\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\python\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 26/26 [==============================] - 2s 3ms/step - loss: 7.3820 - accuracy: 0.4610
# Epoch 2/300
# 26/26 [==============================] - 0s 4ms/step - loss: 2.7254 - accuracy: 0.3951
# Epoch 3/300
# 26/26 [==============================] - 0s 2ms/step - loss: 2.2663 - accuracy: 0.4256
# Epoch 4/300
# 26/26 [==============================] - 0s 3ms/step - loss: 1.9463 - accuracy: 0.4476
# Epoch 5/300
# 26/26 [==============================] - 0s 3ms/step - loss: 1.7107 - accuracy: 0.4488
# Epoch 6/300
# 26/26 [==============================] - 0s 2ms/step - loss: 1.5008 - accuracy: 0.4793
# Epoch 7/300
# 26/26 [==============================] - 0s 2ms/step - loss: 1.3394 - accuracy: 0.5207
# Epoch 8/300
# 26/26 [==============================] - 0s 2ms/step - loss: 1.2214 - accuracy: 0.5463
# Epoch 9/300
# 26/26 [==============================] - 0s 2ms/step - loss: 1.0683 - accuracy: 0.5415
# Epoch 10/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.9542 - accuracy: 0.5878
# Epoch 11/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.8299 - accuracy: 0.6024
# Epoch 12/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.7316 - accuracy: 0.6390
# Epoch 13/300
# 26/26 [==============================] - 0s 3ms/step - loss: 0.6620 - accuracy: 0.6500
# Epoch 14/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.6147 - accuracy: 0.6841
# Epoch 15/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.5613 - accuracy: 0.7134
# Epoch 16/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.5267 - accuracy: 0.7268
# Epoch 17/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.5406 - accuracy: 0.7329
# Epoch 18/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.5104 - accuracy: 0.7439
# Epoch 19/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4802 - accuracy: 0.7744
# Epoch 20/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4684 - accuracy: 0.7732
# Epoch 21/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4691 - accuracy: 0.7659
# Epoch 22/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.4628 - accuracy: 0.7915
# Epoch 23/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4551 - accuracy: 0.7915
# Epoch 24/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4698 - accuracy: 0.
300
# 26/26 [==============================] - 0s 3ms/step - loss: 0.3689 - accuracy: 0.8390
# Epoch 252/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3698 - accuracy: 0.8500
# Epoch 253/300
# 26/26 [==============================] - 0s 3ms/step - loss: 0.3798 - accuracy: 0.8451
# Epoch 254/300
# 26/26 [==============================] - 0s 6ms/step - loss: 0.3733 - accuracy: 0.8427
# Epoch 255/300
# 26/26 [==============================] - 0s 5ms/step - loss: 0.3848 - accuracy: 0.8341
# Epoch 256/300
# 26/26 [==============================] - 0s 3ms/step - loss: 0.3742 - accuracy: 0.8451
# Epoch 257/300
# 26/26 [==============================] - 0s 3ms/step - loss: 0.3720 - accuracy: 0.8354
# Epoch 258/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3748 - accuracy: 0.8402
# Epoch 259/300
# 26/26 [==============================] - 0s 3ms/step - loss: 0.3747 - accuracy: 0.8415
# Epoch 260/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3845 - accuracy: 0.8329
# Epoch 261/300
# 26/26 [==============================] - 0s 3ms/step - loss: 0.4059 - accuracy: 0.8183
# Epoch 262/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3802 - accuracy: 0.8439
# Epoch 263/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3767 - accuracy: 0.8524
# Epoch 264/300
# 26/26 [==============================] - 0s 3ms/step - loss: 0.3737 - accuracy: 0.8378
# Epoch 265/300
# 26/26 [==============================] - 0s 3ms/step - loss: 0.3821 - accuracy: 0.8305
# Epoch 266/300
# 26/26 [==============================] - 0s 3ms/step - loss: 0.3770 - accuracy: 0.8439
# Epoch 267/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3765 - accuracy: 0.8439
# Epoch 268/300
# 26/26 [==============================] - 0s 3ms/step - loss: 0.3863 - accuracy: 0.8390
# Epoch 269/300
# 26/26 [==============================] - 0s 7ms/step - loss: 0.3717 - accuracy: 0.8402
# Epoch 270/300
# 26/26 [==============================] - 0s 3ms/step - loss: 0.3782 - accuracy: 0.8280
# Epoch 271/300
# 26/26 [==============================] - 0s 3ms/step - loss: 0.3680 - accuracy: 0.8476
# Epoch 272/300
# 26/26 [==============================] - 0s 3ms/step - loss: 0.3900 - accuracy: 0.8220
# Epoch 273/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4368 - accuracy: 0.8061
# Epoch 274/300
# 26/26 [==============================] - 0s 3ms/step - loss: 0.3670 - accuracy: 0.8512
# Epoch 275/300
# 26/26 [==============================] - 0s 3ms/step - loss: 0.3844 - accuracy: 0.8378
# Epoch 276/300
# 26/26 [==============================] - 0s 3ms/step - loss: 0.3683 - accuracy: 0.8378
# Epoch 277/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3678 - accuracy: 0.8439
# Epoch 278/300
# 26/26 [==============================] - 0s 3ms/step - loss: 0.3697 - accuracy: 0.8451
# Epoch 279/300
# 26/26 [==============================] - 0s 3ms/step - loss: 0.3631 - accuracy: 0.8451
# Epoch 280/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3682 - accuracy: 0.8463
# Epoch 281/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3686 - accuracy: 0.8488
# Epoch 282/300
# 26/26 [==============================] - 0s 3ms/step - loss: 0.3861 - accuracy: 0.8134
# Epoch 283/300
# 26/26 [==============================] - 0s 4ms/step - loss: 0.3704 - accuracy: 0.8390
# Epoch 284/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3692 - accuracy: 0.8427
# Epoch 285/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3695 - accuracy: 0.8524
# Epoch 286/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3684 - accuracy: 0.8451
# Epoch 287/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3683 - accuracy: 0.8549
# Epoch 288/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.3712 - accuracy: 0.8439
# Epoch 289/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.3956 - accuracy: 0.8378
# Epoch 290/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3942 - accuracy: 0.8402
# Epoch 291/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3769 - accuracy: 0.8549
# Epoch 292/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3805 - accuracy: 0.8415
# Epoch 293/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3811 - accuracy: 0.8378
# Epoch 294/300
# 26/26 [==============================] - 0s 1ms/step - loss: 0.3758 - accuracy: 0.8476
# Epoch 295/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3671 - accuracy: 0.8549
# Epoch 296/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3701 - accuracy: 0.8524
# Epoch 297/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4217 - accuracy: 0.8061
# Epoch 298/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4379 - accuracy: 0.7927
# Epoch 299/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3987 - accuracy: 0.8280
# Epoch 300/300
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3771 - accuracy: 0.8415

# %%
Y_pred_nn = model.predict(X_test)
# Out:
# 7/7 [==============================] - 0s 728us/step

# %%
Y_pred_nn.shape
# Out:
# (205, 1)

# %%
rounded = [round(x[0]) for x in Y_pred_nn]

Y_pred_nn = rounded

# %%
score_nn = round(accuracy_score(Y_pred_nn,Y_test)*100,2)

print("The accuracy score achieved using Neural Network is: "+str(score_nn)+" %")
# Out:
# The accuracy score achieved using Neural Network is: 82.93 %

# %% [markdown]
# VI. Output final score

# %%
scores = [score_lr,score_nb,score_svm,score_knn,score_dt,score_rf,score_xgb,score_nn]
algorithms = ["Logistic Regression","Naive Bayes","Support Vector Machine","K-Nearest Neighbors","Decision Tree","Random Forest","XGBoost","Neural Network"]    

for i in range(len(algorithms)):
    print("The accuracy score achieved using "+algorithms[i]+" is: "+str(scores[i])+" %")
# Out:
# The accuracy score achieved using Logistic Regression is: 86.34 %
# The accuracy score achieved using Naive Bayes is: 85.37 %
# The accuracy score achieved using Support Vector Machine is: 83.9 %
# The accuracy score achieved using K-Nearest Neighbors is: 72.2 %
# The accuracy score achieved using Decision Tree is: 100.0 %
# The accuracy score achieved using Random Forest is: 100.0 %
# The accuracy score achieved using XGBoost is: 100.0 %
# The accuracy score achieved using Neural Network is: 82.93 %

# %%
sns.barplot(x=algorithms, y=scores)
plt.xlabel("Algorithms")
plt.ylabel("Accuracy Score")
plt.show()
